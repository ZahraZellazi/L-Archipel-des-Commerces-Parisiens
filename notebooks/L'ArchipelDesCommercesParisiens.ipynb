# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body { font-family: Arial, sans-serif; margin: 40px; background: #f5f5f5; color: #333; line-height: 1.6; }
#         h1 { text-align: center; color: #ff69b4; font-size: 36px; font-weight: bold; margin-bottom: 10px; }
#         h2 { color: orange; font-size: 28px; font-weight: bold; margin-top: 30px; }
#         h3 { color: #00FFFF; font-size: 22px; margin-top: 20px; }
#         ul { margin-left: 20px; }
#         li { margin: 8px 0; }
#         hr { height: 2px; border: none; background-color: #ff69b4; margin: 20px 0; }
#     </style>
# </head>
# <body>
#
# <h1>🏪 PROJET : "L'ARCHIPEL DES COMMERCES PARISIENS"</h1>
# <h2 style="text-align:center; color:#ff69b4;">🔍 Analyse des clusters commerciaux spontanés à Paris</h2>
# <hr>
#
# <h2>🏪 1. Introduction</h2>
# <p><strong>📌 Goal:</strong></p>
# <p>This project aims to identify and analyze spontaneous commercial clusters in Paris.
# Understanding natural economic agglomeration patterns helps urban planners, investors, and merchants make informed decisions.</p>
#
# <h2>🛠️ Key Objectives</h2>
# <ul>
#     <li>🔄 Map commercial clusters by type</li>
#     <li>📈 Analyze correlations between neighboring shops</li>
#     <li>🏘️ Study the influence of districts on specialization</li>
#     <li>📅 Understand temporal evolution of clusters</li>
# </ul>
#
# <h2>🔑 Definitions</h2>
# <ul>
#     <li>🏷️ <strong>Commercial Cluster:</strong> Natural grouping of similar or complementary shops. Examples: Rue Montorgueil (food), Rue du Faubourg Saint-Antoine (furniture), Avenue Montaigne (luxury)</li>
#     <li>📊 <strong>Commercial Specialization Index:</strong> Concentration of a shop type in a zone vs Paris average. Formula: (Type X shops / total shops in zone) × 100</li>
#     <li>🌐 <strong>Commercial Ecosystem:</strong> Shops interacting in an area, creating synergies and complementarity</li>
# </ul>
#
# <h2>🎯 Business Value</h2>
# <ul>
#     <li>🏛️ City of Paris: Decision support for commercial permits</li>
#     <li>💼 Investors: Identify underutilized zones and niche opportunities</li>
#     <li>🛍️ Merchants: Understand local ecosystems for optimal positioning</li>
#     <li>🏢 Urban Planners: Analyze economic flows and neighborhood vitality</li>
# </ul>
#
# <h2>👥 Stakeholders</h2>
# <ul>
#     <li>🏛️ City of Paris – Urban Planning & Economic Development</li>
#     <li>💼 Real Estate Investors – Developers, property companies</li>
#     <li>🛍️ Future Shop Owners / Franchises</li>
#     <li>🏢 Chamber of Commerce – Business support</li>
#     <li>🎓 Urban Economy Researchers</li>
# </ul>
#
# <h2>📊 Success Criteria</h2>
# <ul>
#     <li>🔍 Identify at least 10 significant clusters not previously documented</li>
#     <li>📈 Highlight counter-intuitive commercial correlations</li>
#     <li>🎯 Produce actionable insights for commercial implantation</li>
#     <li>📱 Create visually clear and pedagogical visualizations</li>
# </ul>
#
# <h2>🚧 Constraints</h2>
# <ul>
#     <li>📅 Deadline: 5 days</li>
#     <li>💾 API limit: 10,000 records per request</li>
#     <li>🔍 Data quality: shop categorization may be inconsistent</li>
#     <li>🌍 Scope: Paris intra-muros only</li>
#     <li>✅ MVP: focus on retail shops, 20 districts, latest available data</li>
# </ul>
#
# <h2>📋 Deliverables</h2>
# <ul>
#     <li>📊 Complete analysis report with methodology and results</li>
#     <li>🗺️ Interactive map of identified clusters</li>
#     <li>📈 Dashboard of key metrics</li>
#     <li>💾 Source code and technical documentation</li>
#     <li>🎤 Summary presentation for stakeholders</li>
# </ul>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             margin: 40px;
#             background: #f0f4f8;
#             color: #2c3e50;
#         }
#         h1, h2, h3 {
#             margin-top: 25px;
#             margin-bottom: 15px;
#             font-family: 'Verdana', sans-serif;
#         }
#         h1 { font-size: 3em; color: #e74c3c; }
#         h2 { font-size: 2em; color: #3498db; border-bottom: 2px solid #3498db; padding-bottom: 5px; }
#         h3 { font-size: 1.5em; color: #2980b9; }
#
#         .section {
#             padding: 25px;
#             margin: 20px 0;
#             border-left: 6px solid #3498db;
#             background: transparent;
#         }
#
#         .highlight {
#             background: #fff3cd;
#             padding: 15px;
#             border-left: 6px solid #ffc107;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .definition {
#             background: #e8f4fd;
#             padding: 15px;
#             border-left: 6px solid #3498db;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .business-value {
#             background: #d5f4e6;
#             padding: 15px;
#             border-left: 6px solid #2ecc71;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         ul { line-height: 1.6; margin-left: 20px; }
#         li { margin: 8px 0; }
#         p { line-height: 1.5; }
#     </style>
# </head>
# <body>
#
# <div class="section">
#     <h1>🏪 PROJET : "L'ARCHIPEL DES COMMERCES PARISIENS"</h1>
#     <h2>🔍 Analyse des clusters commerciaux spontanés à Paris</h2>
# </div>
#
# <div class="section">
#     <h2>🎯 CONTEXTE BUSINESS</h2>
#
#     <div class="business-value">
#         <h3>💡 Problématique Métier</h3>
#         <ul>
#             <li>📈 Optimiser l'implantation commerciale</li>
#             <li>🏙️ Améliorer la planification urbaine</li>
#             <li>🛍️ Comprendre les dynamiques économiques locales</li>
#             <li>🎯 Identifier les opportunités de développement</li>
#         </ul>
#     </div>
#
#     <div class="highlight">
#         <h3>🚀 Valeur Ajoutée Business</h3>
#         <ul>
#             <li><strong>Ville de Paris :</strong> Outil d'aide à la décision pour autorisations commerciales</li>
#             <li><strong>Investisseurs :</strong> Identification des zones sous-exploitées</li>
#             <li><strong>Commerçants :</strong> Compréhension des écosystèmes commerciaux</li>
#             <li><strong>Urbanistes :</strong> Analyse des flux économiques et vitalité des quartiers</li>
#         </ul>
#     </div>
# </div>
#
# <div class="section">
#     <h2>📊 OBJECTIFS DU PROJET</h2>
#     <h3>🎯 Objectif Principal</h3>
#     <p>Identifier et analyser les <strong>clusters commerciaux spontanés</strong> à Paris pour comprendre les logiques d'agglomération économique naturelle.</p>
#
#     <h3>🎯 Objectifs Spécifiques</h3>
#     <ul>
#         <li>🔄 Cartographier les regroupements par typologie de commerce</li>
#         <li>📈 Analyser les corrélations entre types de commerces voisins</li>
#         <li>🏘️ Étudier l'influence des arrondissements sur la spécialisation</li>
#         <li>📅 Comprendre l'évolution temporelle de ces clusters</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🔑 DÉFINITIONS CLÉS</h2>
#
#     <div class="definition">
#         <h3>🏷️ Cluster Commercial Spontané</h3>
#         <p>Regroupement géographique naturel de commerces similaires ou complémentaires, non planifié par les autorités, résultant de dynamiques de marché.</p>
#         <p><strong>Exemples :</strong> Rue Montorgueil (alimentation), Rue du Faubourg Saint-Antoine (ameublement), Avenue Montaigne (luxe)</p>
#     </div>
#
#     <div class="definition">
#         <h3>📊 Indice de Spécialisation Commerciale</h3>
#         <p>Mesure statistique de la concentration d'un type de commerce dans une zone géographique donnée, par rapport à sa distribution moyenne dans Paris.</p>
#         <p><strong>Calcul :</strong> (Nombre de commerces type X dans la zone) / (Nombre total de commerces dans la zone) × 100</p>
#     </div>
#
#     <div class="definition">
#         <h3>🌐 Écosystème Commercial</h3>
#         <p>Ensemble de commerces interagissant dans un espace géographique restreint, créant des synergies et des complémentarités.</p>
#         <p><strong>Caractéristiques :</strong> Complémentarité, proximité, clientèle partagée</p>
#     </div>
# </div>
#
# <div class="section">
#     <h2>🎪 ACTEURS CONCERNÉS</h2>
#     <ul>
#         <li>🏛️ Ville de Paris - Service urbanisme et développement économique</li>
#         <li>💼 Investisseurs immobiliers - Sociétés foncières, promoteurs</li>
#         <li>🛍️ Porteurs de projets commerciaux - Futurs commerçants, franchises</li>
#         <li>🏢 Chambre de Commerce et d'Industrie - Accompagnement des entreprises</li>
#         <li>🎓 Chercheurs en économie urbaine - Universités, laboratoires</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>📈 CRITÈRES DE SUCCÈS</h2>
#     <ul>
#         <li>🔍 Identification d'au moins <strong>10 clusters significatifs</strong> non documentés</li>
#         <li>📊 Mise en évidence de <strong>corrélations commerciales</strong> contre-intuitives</li>
#         <li>🎯 Production d'<strong>insights actionnables</strong></li>
#         <li>📱 Création de <strong>visualisations pédagogiques</strong></li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🚧 CONTRAINTES ET LIMITES</h2>
#     <ul>
#         <li>📅 Délai : 5 jours pour l'ensemble du projet</li>
#         <li>💾 Limitation de l'API à 10 000 enregistrements par requête</li>
#         <li>🔍 Catégorisation parfois imprécise des commerces</li>
#         <li>🌍 Périmètre : Paris intra-muros uniquement</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>📋 LIVRABLES ATTENDUS</h2>
#     <ul>
#         <li>📊 Rapport d'analyse complet avec méthodologie et résultats</li>
#         <li>🗺️ Cartographie interactive des clusters identifiés</li>
#         <li>📈 Dashboard de visualisation des principales métriques</li>
#         <li>💾 Code source et documentation technique</li>
#         <li>🎤 Présentation synthétique pour comité de direction</li>
#     </ul>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             margin: 40px;
#             background: #f0f4f8;
#             color: #2c3e50;
#         }
#         h1, h2, h3 {
#             margin-top: 25px;
#             margin-bottom: 15px;
#             font-family: 'Verdana', sans-serif;
#         }
#         h1 { font-size: 3em; color: #e74c3c; }
#         h2 { font-size: 2em; color: #3498db; border-bottom: 2px solid #3498db; padding-bottom: 5px; }
#         h3 { font-size: 1.5em; color: #2980b9; }
#
#         .section {
#             padding: 25px;
#             margin: 20px 0;
#             border-left: 6px solid #3498db;
#             background: transparent;
#         }
#
#         .highlight {
#             background: #fff3cd;
#             padding: 15px;
#             border-left: 6px solid #ffc107;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .definition {
#             background: #e8f4fd;
#             padding: 15px;
#             border-left: 6px solid #3498db;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .business-value {
#             background: #d5f4e6;
#             padding: 15px;
#             border-left: 6px solid #2ecc71;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         ul { line-height: 1.6; margin-left: 20px; }
#         li { margin: 8px 0; }
#         p { line-height: 1.5; }
#     </style>
# </head>
# <body>
#
# <div class="section">
#     <h1>🏪 PROJET : "L'ARCHIPEL DES COMMERCES PARISIENS"</h1>
#     <h2>🔍 Analyse des clusters commerciaux spontanés à Paris</h2>
# </div>
#
# <div class="section">
#     <h2>🎯 CONTEXTE BUSINESS</h2>
#
#     <div class="business-value">
#         <h3>💡 Problématique Métier</h3>
#         <ul>
#             <li>📈 Optimiser l'implantation commerciale</li>
#             <li>🏙️ Améliorer la planification urbaine</li>
#             <li>🛍️ Comprendre les dynamiques économiques locales</li>
#             <li>🎯 Identifier les opportunités de développement</li>
#         </ul>
#     </div>
#
#     <div class="highlight">
#         <h3>🚀 Valeur Ajoutée Business</h3>
#         <ul>
#             <li><strong>Ville de Paris :</strong> Outil d'aide à la décision pour autorisations commerciales</li>
#             <li><strong>Investisseurs :</strong> Identification des zones sous-exploitées</li>
#             <li><strong>Commerçants :</strong> Compréhension des écosystèmes commerciaux</li>
#             <li><strong>Urbanistes :</strong> Analyse des flux économiques et vitalité des quartiers</li>
#         </ul>
#     </div>
# </div>
#
# <div class="section">
#     <h2>📊 OBJECTIFS DU PROJET</h2>
#     <h3>🎯 Objectif Principal</h3>
#     <p>Identifier et analyser les <strong>clusters commerciaux spontanés</strong> à Paris pour comprendre les logiques d'agglomération économique naturelle.</p>
#
#     <h3>🎯 Objectifs Spécifiques</h3>
#     <ul>
#         <li>🔄 Cartographier les regroupements par typologie de commerce</li>
#         <li>📈 Analyser les corrélations entre types de commerces voisins</li>
#         <li>🏘️ Étudier l'influence des arrondissements sur la spécialisation</li>
#         <li>📅 Comprendre l'évolution temporelle de ces clusters</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🔑 DÉFINITIONS CLÉS</h2>
#
#     <div class="definition">
#         <h3>🏷️ Cluster Commercial Spontané</h3>
#         <p>Regroupement géographique naturel de commerces similaires ou complémentaires, non planifié par les autorités, résultant de dynamiques de marché.</p>
#         <p><strong>Exemples :</strong> Rue Montorgueil (alimentation), Rue du Faubourg Saint-Antoine (ameublement), Avenue Montaigne (luxe)</p>
#     </div>
#
#     <div class="definition">
#         <h3>📊 Indice de Spécialisation Commerciale</h3>
#         <p>Mesure statistique de la concentration d'un type de commerce dans une zone géographique donnée, par rapport à sa distribution moyenne dans Paris.</p>
#         <p><strong>Calcul :</strong> (Nombre de commerces type X dans la zone) / (Nombre total de commerces dans la zone) × 100</p>
#     </div>
#
#     <div class="definition">
#         <h3>🌐 Écosystème Commercial</h3>
#         <p>Ensemble de commerces interagissant dans un espace géographique restreint, créant des synergies et des complémentarités.</p>
#         <p><strong>Caractéristiques :</strong> Complémentarité, proximité, clientèle partagée</p>
#     </div>
# </div>
#
# <div class="section">
#     <h2>🎪 ACTEURS CONCERNÉS</h2>
#     <ul>
#         <li>🏛️ Ville de Paris - Service urbanisme et développement économique</li>
#         <li>💼 Investisseurs immobiliers - Sociétés foncières, promoteurs</li>
#         <li>🛍️ Porteurs de projets commerciaux - Futurs commerçants, franchises</li>
#         <li>🏢 Chambre de Commerce et d'Industrie - Accompagnement des entreprises</li>
#         <li>🎓 Chercheurs en économie urbaine - Universités, laboratoires</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>📈 CRITÈRES DE SUCCÈS</h2>
#     <ul>
#         <li>🔍 Identification d'au moins <strong>10 clusters significatifs</strong> non documentés</li>
#         <li>📊 Mise en évidence de <strong>corrélations commerciales</strong> contre-intuitives</li>
#         <li>🎯 Production d'<strong>insights actionnables</strong></li>
#         <li>📱 Création de <strong>visualisations pédagogiques</strong></li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🚧 CONTRAINTES ET LIMITES</h2>
#     <ul>
#         <li>📅 Déla

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         body {
#             font-family: 'Arial', sans-serif;
#             margin: 40px;
#             background: #f0f4f8;
#             color: #2c3e50;
#         }
#         h1, h2, h3 {
#             margin-top: 25px;
#             margin-bottom: 15px;
#             font-family: 'Verdana', sans-serif;
#         }
#         h1 { font-size: 3em; color: #e74c3c; }
#         h2 { font-size: 2em; color: #3498db; border-bottom: 2px solid #3498db; padding-bottom: 5px; }
#         h3 { font-size: 1.5em; color: #2980b9; }
#
#         .section {
#             padding: 25px;
#             margin: 20px 0;
#             border-left: 6px solid #3498db;
#             background: transparent;
#         }
#
#         .highlight {
#             background: #fff3cd;
#             padding: 15px;
#             border-left: 6px solid #ffc107;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .definition {
#             background: #e8f4fd;
#             padding: 15px;
#             border-left: 6px solid #3498db;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         .business-value {
#             background: #d5f4e6;
#             padding: 15px;
#             border-left: 6px solid #2ecc71;
#             margin: 15px 0;
#             border-radius: 8px;
#         }
#
#         ul { line-height: 1.6; margin-left: 20px; }
#         li { margin: 8px 0; }
#         p { line-height: 1.5; }
#     </style>
# </head>
# <body>
#
# <div class="section">
#     <h1>🏪 PROJET : "L'ARCHIPEL DES COMMERCES PARISIENS"</h1>
#     <h2>🔍 Analyse des clusters commerciaux spontanés à Paris</h2>
# </div>
#
# <div class="section">
#     <h2>🎯 CONTEXTE BUSINESS</h2>
#
#     <div class="business-value">
#         <h3>💡 Problématique Métier</h3>
#         <ul>
#             <li>📈 Optimiser l'implantation commerciale</li>
#             <li>🏙️ Améliorer la planification urbaine</li>
#             <li>🛍️ Comprendre les dynamiques économiques locales</li>
#             <li>🎯 Identifier les opportunités de développement</li>
#         </ul>
#     </div>
#
#     <div class="highlight">
#         <h3>🚀 Valeur Ajoutée Business</h3>
#         <ul>
#             <li><strong>Ville de Paris :</strong> Outil d'aide à la décision pour autorisations commerciales</li>
#             <li><strong>Investisseurs :</strong> Identification des zones sous-exploitées</li>
#             <li><strong>Commerçants :</strong> Compréhension des écosystèmes commerciaux</li>
#             <li><strong>Urbanistes :</strong> Analyse des flux économiques et vitalité des quartiers</li>
#         </ul>
#     </div>
# </div>
#
# <div class="section">
#     <h2>📊 OBJECTIFS DU PROJET</h2>
#     <h3>🎯 Objectif Principal</h3>
#     <p>Identifier et analyser les <strong>clusters commerciaux spontanés</strong> à Paris pour comprendre les logiques d'agglomération économique naturelle.</p>
#
#     <h3>🎯 Objectifs Spécifiques</h3>
#     <ul>
#         <li>🔄 Cartographier les regroupements par typologie de commerce</li>
#         <li>📈 Analyser les corrélations entre types de commerces voisins</li>
#         <li>🏘️ Étudier l'influence des arrondissements sur la spécialisation</li>
#         <li>📅 Comprendre l'évolution temporelle de ces clusters</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🔑 DÉFINITIONS CLÉS</h2>
#
#     <div class="definition">
#         <h3>🏷️ Cluster Commercial Spontané</h3>
#         <p>Regroupement géographique naturel de commerces similaires ou complémentaires, non planifié par les autorités, résultant de dynamiques de marché.</p>
#         <p><strong>Exemples :</strong> Rue Montorgueil (alimentation), Rue du Faubourg Saint-Antoine (ameublement), Avenue Montaigne (luxe)</p>
#     </div>
#
#     <div class="definition">
#         <h3>📊 Indice de Spécialisation Commerciale</h3>
#         <p>Mesure statistique de la concentration d'un type de commerce dans une zone géographique donnée, par rapport à sa distribution moyenne dans Paris.</p>
#         <p><strong>Calcul :</strong> (Nombre de commerces type X dans la zone) / (Nombre total de commerces dans la zone) × 100</p>
#     </div>
#
#     <div class="definition">
#         <h3>🌐 Écosystème Commercial</h3>
#         <p>Ensemble de commerces interagissant dans un espace géographique restreint, créant des synergies et des complémentarités.</p>
#         <p><strong>Caractéristiques :</strong> Complémentarité, proximité, clientèle partagée</p>
#     </div>
# </div>
#
# <div class="section">
#     <h2>🎪 ACTEURS CONCERNÉS</h2>
#     <ul>
#         <li>🏛️ Ville de Paris - Service urbanisme et développement économique</li>
#         <li>💼 Investisseurs immobiliers - Sociétés foncières, promoteurs</li>
#         <li>🛍️ Porteurs de projets commerciaux - Futurs commerçants, franchises</li>
#         <li>🏢 Chambre de Commerce et d'Industrie - Accompagnement des entreprises</li>
#         <li>🎓 Chercheurs en économie urbaine - Universités, laboratoires</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>📈 CRITÈRES DE SUCCÈS</h2>
#     <ul>
#         <li>🔍 Identification d'au moins <strong>10 clusters significatifs</strong> non documentés</li>
#         <li>📊 Mise en évidence de <strong>corrélations commerciales</strong> contre-intuitives</li>
#         <li>🎯 Production d'<strong>insights actionnables</strong></li>
#         <li>📱 Création de <strong>visualisations pédagogiques</strong></li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>🚧 CONTRAINTES ET LIMITES</h2>
#     <ul>
#         <li>📅 Délai : 5 jours pour l'ensemble du projet</li>
#         <li>💾 Limitation de l'API à 10 000 enregistrements par requête</li>
#         <li>🔍 Catégorisation parfois imprécise des commerces</li>
#         <li>🌍 Périmètre : Paris intra-muros uniquement</li>
#     </ul>
# </div>
#
# <div class="section">
#     <h2>📋 LIVRABLES ATTENDUS</h2>
#     <ul>
#         <li>📊 Rapport d'analyse complet avec méthodologie et résultats</li>
#         <li>🗺️ Cartographie interactive des clusters identifiés</li>
#         <li>📈 Dashboard de visualisation des principales métriques</li>
#         <li>💾 Code source et documentation technique</li>
#         <li>🎤 Présentation synthétique pour comité de direction</li>
#     </ul>
# </div>
#
# </body>
# </html>
